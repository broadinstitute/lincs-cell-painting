# %% [markdown]
# # Merging Compound files distributed by CLUE
#
# We consolidate drug and sample resources information into a single file for easier downstream processing.
#
# The data were originally retrieved from https://clue.io/repurposing.
# See [`clue/README.md`](clue/README.md) for more details.

# %%
import os
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
data_dir = "clue"
date = "20180907"

# %%
drug_file = os.path.join(data_dir, "repurposing_drugs_{}.txt".format(date))
drug_df = pd.read_csv(drug_file, encoding = "ISO-8859-1", sep='\t', skiprows=9)

print(drug_df.shape)
drug_df.head(2)
# Out:
# (6125, 6)
#                      pert_iname clinical_phase  \
# 0  [sar9,met(o2)11]-substance-p    Preclinical
# 1                     A-1070722    Preclinical
#
#                                   moa       target disease_area indication
# 0               tachykinin antagonist        TACR1          NaN        NaN
# 1  glycogen synthase kinase inhibitor  GSK3A|GSK3B          NaN        NaN

# %%
sample_file = os.path.join(data_dir, "repurposing_samples_{}.txt".format(date))
sample_df = pd.read_csv(sample_file, encoding = "ISO-8859-1", sep='\t', skiprows=9)

print(sample_df.shape)
sample_df.head(2)
# Out:
# (10147, 12)
#                  broad_id                                         pert_iname  \
# 0  BRD-K89787693-001-01-1                       [sar9,met(o2)11]-substance-p
# 1  BRD-K88956297-003-01-9  1-((Z)-3-Chloroallyl)-1,3,5,7-tetraazaadamanta...
#
#    qc_incompatible  purity     vendor catalog_no  \
# 0                0     NaN     Tocris       1178
# 1                0   94.41  BidePharm    BD51690
#
#                                          vendor_name expected_mass  \
# 0  2-({5-amino-2-[({1-[6-amino-2-({[1-(2-amino-5-...      1,392.73
# 1  1-((Z)-3-Chloroallyl)-1,3,5,7-tetraazaadamanta...       215.106
#
#                                               smiles  \
# 0  CC(C)C[C@H](NC(=O)CN(C)C(=O)[C@H](Cc1ccccc1)NC...
# 1                    Cl\C=C/C[N+]12CN3CN(CN(C3)C1)C2
#
#                       InChIKey  pubchem_cid deprecated_broad_id
# 0  OUPXSLGGCPUZJJ-SARDKLJWSA-N     163829.0                 NaN
# 1  LDLCEGCJYSDJLX-UPHRSURJSA-N    5846454.0                 NaN

# %% [markdown]
# ## Checking for `pert_iname` Discrepancies

# %%
assert len(set(drug_df.pert_iname.values).difference(set(sample_df.pert_iname))) == 0
set(sample_df.pert_iname.values).difference(set(drug_df.pert_iname))
# Out:
# {'YM-298198-desmethyl', 'golgicide-A'}

# %% [markdown]
# Two perturbation names (`pert_iname`) are inconsistent.
# Work towards reconciliation.

# %% [markdown]
# ### `YM-298198-desmethyl`

# %%
sample_df.loc[sample_df.pert_iname.str.contains("298198"), :]
# Out:
#                      broad_id           pert_iname  qc_incompatible  purity  \
# 10019  BRD-K59650319-003-03-3            YM-298198                0   61.48
# 10020  BRD-K48059230-003-02-9  YM-298198-desmethyl                0   68.02
#
#        vendor catalog_no              vendor_name expected_mass  \
# 10019  Tocris       2448  YM 298198 hydrochloride       342.151
# 10020  Tocris       2447      Desmethyl-YM 298198       328.136
#
#                                         smiles                     InChIKey  \
# 10019  CN(C1CCCCC1)C(=O)c1sc2nc3ccc(N)cc3n2c1C  KCBXOMYXOBVLED-UHFFFAOYSA-N
# 10020   Cc1c(sc2nc3ccc(N)cc3n12)C(=O)NC1CCCCC1  VWOMTTIMBHBPBI-UHFFFAOYSA-N
#
#        pubchem_cid deprecated_broad_id
# 10019    9819432.0                 NaN
# 10020   11716890.0                 NaN

# %%
ym_drug = drug_df.loc[drug_df.pert_iname.str.contains("298198"), :].reset_index(drop=True)
ym_drug.loc[0, "pert_iname"] = "YM-298198-desmethyl"
ym_drug
# Out:
#             pert_iname clinical_phase                            moa target  \
# 0  YM-298198-desmethyl    Preclinical  glutamate receptor antagonist   GRM1
#
#   disease_area indication
# 0          NaN        NaN

# %%
# solve the YM-298198 problem
drug_df = pd.concat([drug_df, ym_drug], axis="rows").reset_index(drop=True)

# %% [markdown]
# #### `YM-298198-desmethyl` is absent in the drug data
#
# [`YM-298198-desmethyl`](https://www.tocris.com/products/desmethyl-ym-298198_2447) is a derivative of [`YM-298198`](https://www.tocris.com/products/ym-298198-hydrochloride_2448), and therefore has a different structure. However, their MOA and target is the same.

# %% [markdown]
# ### `golgicide-A`

# %%
sample_df.loc[sample_df.pert_iname.str.contains("golgicide"), :]
# Out:
#                     broad_id   pert_iname  qc_incompatible  purity   vendor  \
# 4255  BRD-A57886255-001-02-9  golgicide-A                0   97.26  Selleck
# 4256  BRD-A57886255-001-01-1  golgicide-a                0   96.27   Tocris
#
#      catalog_no  vendor_name expected_mass  \
# 4255      S7266  Golgicide A       284.113
# 4256       3584  Golgicide A       284.113
#
#                                             smiles  \
# 4255  Fc1cc(F)c2NC([C@@H]3CC=C[C@@H]3c2c1)c1cccnc1
# 4256  Fc1cc(F)c2NC([C@@H]3CC=C[C@@H]3c2c1)c1cccnc1
#
#                          InChIKey  pubchem_cid     deprecated_broad_id
# 4255  NJZHEQOUHLZCOX-FTLRAWMYSA-N   25113626.0  BRD-A53244165-001-01-6
# 4256  NJZHEQOUHLZCOX-FTLRAWMYSA-N   25113626.0                     NaN

# %%
drug_df.loc[drug_df.pert_iname.str.contains("golgicide"), :]
# Out:
#        pert_iname clinical_phase            moa target disease_area indication
# 2383  golgicide-a    Preclinical  ARF inhibitor   GBF1          NaN        NaN

# %% [markdown]
# #### `golgicide` only differs by a capitalization and is equivalent

# %%
# Solve the golgicide problem
sample_df.loc[sample_df.pert_iname.str.contains("golgicide"), "pert_iname"] = "golgicide-a"

# %%
# Now, assert that there are no differences
assert len(set(sample_df.pert_iname.values).difference(set(drug_df.pert_iname))) == 0

# %% [markdown]
# ## Merge the Samples and Drugs data

# %%
combined_df = (
    drug_df.merge(
        sample_df,
        on="pert_iname",
        how="inner"
    )
    .reset_index(drop=True)
)

# Move broad_id to first column
col_order = combined_df.columns.tolist()
col_order.insert(0, col_order.pop(col_order.index('broad_id')))
combined_df = combined_df.loc[:, col_order]

# Output to file
output_file = "repurposing_info"
combined_df.to_csv("{}.tsv".format(output_file), sep='\t', index=False)

print(combined_df.shape)
combined_df.head()
# Out:
# (10147, 17)
#                  broad_id                    pert_iname clinical_phase  \
# 0  BRD-K89787693-001-01-1  [sar9,met(o2)11]-substance-p    Preclinical
# 1  BRD-K70329400-001-02-5                     A-1070722    Preclinical
# 2  BRD-K59060513-001-02-5                        A-1120    Preclinical
# 3  BRD-K38019854-323-01-4                      A-317491    Preclinical
# 4  BRD-K38019854-001-01-6                      A-317491    Preclinical
#
#                                   moa       target disease_area indication  \
# 0               tachykinin antagonist        TACR1          NaN        NaN
# 1  glycogen synthase kinase inhibitor  GSK3A|GSK3B          NaN        NaN
# 2            retinoid receptor ligand         RBP4          NaN        NaN
# 3      purinergic receptor antagonist        P2RX3          NaN        NaN
# 4      purinergic receptor antagonist        P2RX3          NaN        NaN
#
#    qc_incompatible  purity     vendor catalog_no  \
# 0                0     NaN     Tocris       1178
# 1                0   97.36     Tocris       4431
# 2                0   83.72     Tocris       3793
# 3                0   98.69  MedChemEx  HY-15568A
# 4                0   98.06  MedChemEx   HY-15568
#
#                                          vendor_name expected_mass  \
# 0  2-({5-amino-2-[({1-[6-amino-2-({[1-(2-amino-5-...      1,392.73
# 1                                          A 1070722       362.099
# 2                                             A 1120       392.135
# 3                     A-317491 (sodium salt hydrate)       565.174
# 4                                           A-317491       565.174
#
#                                               smiles  \
# 0  CC(C)C[C@H](NC(=O)CN(C)C(=O)[C@H](Cc1ccccc1)NC...
# 1        COc1ccc2c(NC(=O)Nc3cccc(n3)C(F)(F)F)ccnc2c1
# 2     OC(=O)c1ccccc1NC(=O)N1CCC(CC1)c1ccccc1C(F)(F)F
# 3  OC(=O)c1cc(C(O)=O)c(cc1C(O)=O)C(=O)N(Cc1cccc(O...
# 4  OC(=O)c1cc(C(O)=O)c(cc1C(O)=O)C(=O)N(Cc1cccc(O...
#
#                       InChIKey  pubchem_cid deprecated_broad_id
# 0  OUPXSLGGCPUZJJ-SARDKLJWSA-N     163829.0                 NaN
# 1  VQPBIJGXSXEOCU-UHFFFAOYSA-N   49830684.0                 NaN
# 2  MEAQCLPMSVEOQF-UHFFFAOYSA-N   25138295.0                 NaN
# 3  VQGBOYBIENNKMI-LJAQVGFWSA-N    9829395.0                 NaN
# 4  VQGBOYBIENNKMI-LJAQVGFWSA-N    9829395.0                 NaN

# %% [markdown]
# ## Create a "Long" version where we split MOA and Target delimiters
#
# Certain compounds have multiple MOA classes and targets that are delimited by pipes (`|`).
# Each MOA class and target can be considered to have equal support (see https://github.com/broadinstitute/lincs-cell-painting/issues/5).
#
# Split the combined data on both MOA and target along each pipe and elongate the table.
# This is done to reduce computational burden of multiple downstream analyses performing the same splits.

# %%
# The splitting strategy does not work with missing values
# Add a dummy variable, that will be replaced downstream
combined_df.moa = combined_df.moa.fillna("replace_with_na")
combined_df.target = combined_df.target.fillna("replace_with_na")

# %%
# Make sure the original index is preserved
split_col_index = "{}_index".format(output_file)

# %%
moa_split_df = (
    pd.DataFrame(combined_df.moa.str.split("|").tolist(), index=combined_df.index)
    .stack()
    .reset_index()
)
moa_split_df.columns = [split_col_index, "_", "moa_unique"]

print(moa_split_df.shape)
moa_split_df.head()
# Out:
# (11253, 3)
#    repurposing_info_index  _                          moa_unique
# 0                       0  0               tachykinin antagonist
# 1                       1  0  glycogen synthase kinase inhibitor
# 2                       2  0            retinoid receptor ligand
# 3                       3  0      purinergic receptor antagonist
# 4                       4  0      purinergic receptor antagonist

# %%
target_split_df = (
    pd.DataFrame(combined_df.target.str.split("|").tolist(), index=combined_df.index)
    .stack()
    .reset_index()
)

target_split_df.columns = [split_col_index, "_", "target_unique"]

print(target_split_df.shape)
target_split_df.head()
# Out:
# (27778, 3)
#    repurposing_info_index  _ target_unique
# 0                       0  0         TACR1
# 1                       1  0         GSK3A
# 2                       1  1         GSK3B
# 3                       2  0          RBP4
# 4                       3  0         P2RX3

# %%
long_combined_df = (
    combined_df
    .merge(
        moa_split_df.loc[:, [split_col_index, "moa_unique"]],
        left_index=True,
        right_on=split_col_index,
        how="left"
    )
    .merge(
        target_split_df.loc[:, [split_col_index, "target_unique"]],
        on=split_col_index,
        how="left"
    )
    .reset_index(drop=True)
)

# Put back missing values
long_combined_df.loc[long_combined_df.moa == "replace_with_na", "moa"] = np.nan
long_combined_df.loc[long_combined_df.moa_unique == "replace_with_na", "moa_unique"] = np.nan
long_combined_df.loc[long_combined_df.target == "replace_with_na", "target"] = np.nan
long_combined_df.loc[long_combined_df.target_unique == "replace_with_na", "target_unique"] = np.nan

# Output to file
output_file = "repurposing_info_long.tsv"
long_combined_df.to_csv(output_file, sep='\t', index=False)

print(long_combined_df.shape)
long_combined_df.head()
# Out:
# (34328, 20)
#                  broad_id                    pert_iname clinical_phase  \
# 0  BRD-K89787693-001-01-1  [sar9,met(o2)11]-substance-p    Preclinical
# 1  BRD-K70329400-001-02-5                     A-1070722    Preclinical
# 2  BRD-K70329400-001-02-5                     A-1070722    Preclinical
# 3  BRD-K59060513-001-02-5                        A-1120    Preclinical
# 4  BRD-K38019854-323-01-4                      A-317491    Preclinical
#
#                                   moa       target disease_area indication  \
# 0               tachykinin antagonist        TACR1          NaN        NaN
# 1  glycogen synthase kinase inhibitor  GSK3A|GSK3B          NaN        NaN
# 2  glycogen synthase kinase inhibitor  GSK3A|GSK3B          NaN        NaN
# 3            retinoid receptor ligand         RBP4          NaN        NaN
# 4      purinergic receptor antagonist        P2RX3          NaN        NaN
#
#    qc_incompatible  purity     vendor catalog_no  \
# 0                0     NaN     Tocris       1178
# 1                0   97.36     Tocris       4431
# 2                0   97.36     Tocris       4431
# 3                0   83.72     Tocris       3793
# 4                0   98.69  MedChemEx  HY-15568A
#
#                                          vendor_name expected_mass  \
# 0  2-({5-amino-2-[({1-[6-amino-2-({[1-(2-amino-5-...      1,392.73
# 1                                          A 1070722       362.099
# 2                                          A 1070722       362.099
# 3                                             A 1120       392.135
# 4                     A-317491 (sodium salt hydrate)       565.174
#
#                                               smiles  \
# 0  CC(C)C[C@H](NC(=O)CN(C)C(=O)[C@H](Cc1ccccc1)NC...
# 1        COc1ccc2c(NC(=O)Nc3cccc(n3)C(F)(F)F)ccnc2c1
# 2        COc1ccc2c(NC(=O)Nc3cccc(n3)C(F)(F)F)ccnc2c1
# 3     OC(=O)c1ccccc1NC(=O)N1CCC(CC1)c1ccccc1C(F)(F)F
# 4  OC(=O)c1cc(C(O)=O)c(cc1C(O)=O)C(=O)N(Cc1cccc(O...
#
#                       InChIKey  pubchem_cid deprecated_broad_id  \
# 0  OUPXSLGGCPUZJJ-SARDKLJWSA-N     163829.0                 NaN
# 1  VQPBIJGXSXEOCU-UHFFFAOYSA-N   49830684.0                 NaN
# 2  VQPBIJGXSXEOCU-UHFFFAOYSA-N   49830684.0                 NaN
# 3  MEAQCLPMSVEOQF-UHFFFAOYSA-N   25138295.0                 NaN
# 4  VQGBOYBIENNKMI-LJAQVGFWSA-N    9829395.0                 NaN
#
#    repurposing_info_index                          moa_unique target_unique
# 0                       0               tachykinin antagonist         TACR1
# 1                       1  glycogen synthase kinase inhibitor         GSK3A
# 2                       1  glycogen synthase kinase inhibitor         GSK3B
# 3                       2            retinoid receptor ligand          RBP4
# 4                       3      purinergic receptor antagonist         P2RX3

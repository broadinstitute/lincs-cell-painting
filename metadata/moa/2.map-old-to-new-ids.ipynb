# %% [markdown]
# # Create Map between Old and New IDs
#
# Many Broad and Perturbation IDs have deprecated IDs.
# I will use this notebook to generate a map between current and deprecated/legacy identifiers.

# %%
import os
import pandas as pd

# %%
# Load and subset repurposing info to deprecated values
annotation_df = (
    pd.read_csv("repurposing_info.tsv", sep='\t')
    .dropna(subset=["deprecated_broad_id"])
    .reset_index(drop=True)
)

print(annotation_df.shape)
annotation_df.head(3)
# Out:
# (764, 17)
#                  broad_id pert_iname clinical_phase  \
# 0  BRD-K76894955-001-02-1   A-804598    Preclinical
# 1  BRD-K17443395-065-03-0   abacavir       Launched
# 2  BRD-K17443395-065-02-2   abacavir       Launched
#
#                                           moa target        disease_area  \
# 0              purinergic receptor antagonist  P2RX7                 NaN
# 1  nucleoside reverse transcriptase inhibitor    NaN  infectious disease
# 2  nucleoside reverse transcriptase inhibitor    NaN  infectious disease
#
#                              indication  qc_incompatible  purity       vendor  \
# 0                                   NaN                0   98.54       Tocris
# 1  human immunodeficiency virus (HIV-1)                0   95.95       Tocris
# 2  human immunodeficiency virus (HIV-1)                0   98.81  MicroSource
#
#   catalog_no           vendor_name expected_mass  \
# 0       4473              A 804598       315.148
# 1       4148  Abacavir hemisulfate       286.154
# 2    1502410      ABACAVIR SULFATE       286.154
#
#                                               smiles  \
# 0         C[C@H](\N=C(\NC#N)Nc1cccc2ncccc12)c1ccccc1
# 1  Nc1nc(NC2CC2)c2ncn([C@@H]3C[C@H](CO)C=C3)c2n1 ...
# 2  Nc1nc(NC2CC2)c2ncn([C@@H]3C[C@H](CO)C=C3)c2n1 ...
#
#                       InChIKey  pubchem_cid     deprecated_broad_id
# 0  PQYCRDPLPKGSME-AWEZNQCLSA-N   53325874.0  BRD-K94313941-001-01-9
# 1  MCGSCOLBFJQGHM-SCZZXKLOSA-N     441300.0  BRD-M55852627-065-01-7
# 2  MCGSCOLBFJQGHM-SCZZXKLOSA-N     441300.0  BRD-A95032015-065-01-2

# %%
# Split deprecated broad IDs
deprecated_id_df = (
    pd.DataFrame(
        annotation_df.deprecated_broad_id.str.split("|").tolist(),
        index=annotation_df.broad_id
    )
    .stack()
    .reset_index()
    .drop("level_1", axis="columns")
)

deprecated_id_df.columns = ["broad_id", "deprecated_broad_id"]
deprecated_id_df = (
    deprecated_id_df
    .assign(
        pert_id=deprecated_id_df.broad_id.str.slice(0, 13),
        deprecated_pert_id=deprecated_id_df.deprecated_broad_id.str.slice(0, 13)
    )
    .drop_duplicates()
)

col_order = ["broad_id", "pert_id", "deprecated_broad_id", "deprecated_pert_id"]
deprecated_id_df = deprecated_id_df.loc[:, col_order]

print(deprecated_id_df.shape)
deprecated_id_df.head()
# Out:
# (809, 4)
#                  broad_id        pert_id     deprecated_broad_id  \
# 0  BRD-K76894955-001-02-1  BRD-K76894955  BRD-K94313941-001-01-9
# 1  BRD-K17443395-065-03-0  BRD-K17443395  BRD-M55852627-065-01-7
# 2  BRD-K17443395-065-02-2  BRD-K17443395  BRD-A95032015-065-01-2
# 3  BRD-K17443395-065-01-4  BRD-K17443395  BRD-M42309903-065-03-5
# 4  BRD-K50071428-001-03-3  BRD-K50071428  BRD-K00111504-001-01-9
#
#   deprecated_pert_id
# 0      BRD-K94313941
# 1      BRD-M55852627
# 2      BRD-A95032015
# 3      BRD-M42309903
# 4      BRD-K00111504

# %%
# Output file
output_file = os.path.join("repurposing_old_to_new_broad_ids_map.tsv")
deprecated_id_df.to_csv(output_file, sep='\t', index=False)
